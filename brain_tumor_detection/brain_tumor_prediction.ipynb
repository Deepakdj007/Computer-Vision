# %%
from ultralytics import YOLO

# %%
trained_model = YOLO(r'D:\LEARNING\COPMPUTER_VISION\brain-tumor-detection\runs\detect\train2\weights\best.pt')

# %%
results = trained_model(r'D:\LEARNING\COPMPUTER_VISION\brain-tumor-detection\image.png')
# Out:
# image 1/1 D:\LEARNING\COPMPUTER_VISION\brain-tumor-detection\image.png: 512x640 2 negatives, 3 positives, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 25.3ms postprocess per image at shape (1, 3, 512, 640)

# %%
import matplotlib.pyplot as plt
from PIL import Image
# Ensure matplotlib inline mode
# %matplotlib inline
# Assuming results[0].plot() returns an array
image_array = results[0].plot()

# Display the image
plt.imshow(image_array)
plt.axis('off')  # Hide axes
plt.show()
